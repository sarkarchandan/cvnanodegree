# %% [markdown]
# # Color Threshold, Green Screen

# %% [markdown]
# ### Import resources

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np
import cv2

# %matplotlib inline

# %% [markdown]
# ### Read in and display the image

# %%
# Read in the image
image = mpimg.imread('images/car_green_screen.jpg')

# Print out the image dimensions (height, width, and depth (color))
print('Image dimensions:', image.shape)
# Out:
# Image dimensions: (450, 660, 3)

# %%
# Display the image
plt.imshow(image)

# %% [markdown]
# ### Define the color threshold

# %%
## TODO: Define our color selection boundaries in RGB values
lower_green = np.array([0, 240, 0]) 
upper_green = np.array([150, 255, 150])

# %% [markdown]
# ### Create a mask

# %%
# Define the masked area
mask = cv2.inRange(image, lower_green, upper_green)

# Vizualize the mask
plt.imshow(mask, cmap='gray')

# %%
# Mask the image to let the car show through
masked_image = np.copy(image)

masked_image[mask != 0] = [0, 0, 0]

# Display it!
plt.imshow(masked_image)

# %% [markdown]
# ### Mask and add a background image

# %%
# Load in a background image, and convert it to RGB 
background_image:np.ndarray = mpimg.imread('images/sky.jpg')

## TODO: Crop it or resize the background to be the right size (450x660)
background_image = background_image[:image.shape[0], :image.shape[1], :]

## TODO: Mask the cropped background so that the car area is blocked
# Hint mask the opposite area of the previous image
masked_background: np.ndarray = background_image.copy()
masked_background[mask == 0] = [0, 0, 0]

## TODO: Display the background and make sure 
plt.imshow(masked_background, cmap='gray')

# %% [markdown]
# ### Create a complete image

# %%
## TODO: Add the two images together to create a complete image!
complete_image: np.ndarray = masked_image + masked_background

# %%
plt.imshow(complete_image)
